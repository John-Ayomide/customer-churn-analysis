# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
df = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')

print("Data loaded successfully")
print("Shape:", df.shape)
# Out:
# Data loaded successfully
# Shape: (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("Churn Counts:")
print(df['Churn'].value_counts())

print("\nChurn Rate:")
print(df['Churn'].value_counts(normalize=True).round(3))
# Out:
# Churn Counts:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Rate:
# Churn
# No     0.735
# Yes    0.265
# Name: proportion, dtype: float64

# %%
# ================================================
# ANALYTICAL OBSERVATION 1
# ================================================

observation = """
FINDING: High Customer Churn Rate Identified

- Total customers analysed: 7,043
- Customers retained: 5,174 (73.5%)
- Customers churned: 1,869 (26.5%)

INSIGHT: The churn rate of 26.5% significantly exceeds the 
telecom industry average of 10-15%. This means the company 
is losing approximately 1 in 4 customers representing a 
substantial revenue risk.

BUSINESS QUESTION: What is driving this unusually high churn rate?
This analysis will investigate the key factors behind customer departure.
"""

print(observation)
# Out:
# FINDING: High Customer Churn Rate Identified
#
# - Total customers analysed: 7,043
# - Customers retained: 5,174 (73.5%)
# - Customers churned: 1,869 (26.5%)
#
# INSIGHT: The churn rate of 26.5% significantly exceeds the
# telecom industry average of 10-15%. This means the company
# is losing approximately 1 in 4 customers representing a
# substantial revenue risk.
#
# BUSINESS QUESTION: What is driving this unusually high churn rate?
# This analysis will investigate the key factors behind customer departure.
